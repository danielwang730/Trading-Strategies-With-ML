# %% [markdown]
# # 00 LSTM Model Feature Engineering Day Data
# In this notebook, I will obtain the features that I want to use in my LSTM models, and I will download the processed data into another parquet file for easier access.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from datetime import date
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import heatmap
import dask
import dask.dataframe as dd
from dask import delayed
from pyarrow.parquet import ParquetFile
import pyarrow as pa
from tqdm import tqdm

import tulipy as ti

import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.decomposition import KernelPCA
from sklearn.decomposition import IncrementalPCA

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras import initializers
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import register_keras_serializable
from tensorflow.keras.optimizers import SGD
import keras_tuner as kt
from keras_tuner import HyperParameters

import os
import sys
import warnings

# %% [markdown]
# # Data Loading and Initial Feature Engineering for LSTM Model
# I will start by getting the day data and minute data in. Both of these sets of data were obtained from FRD, and both were cleaned in a separate notebook. The day data was created directly from the 1-min data, so the numbers should match perfectly.
#
# Here are a few caveats about the data loading:
# 1. I might only choose certain tickers, perhaps starting with the top 1,000 with the highest prices (or by market cap). To do that, I'll need to obtain a list of tickers with their market caps, that also matches the data that I have.
# 2. I will need to obtain a list of stocks with their respective sectors. Specifically, I want to reduce the number of stocks in the "Other" category as much as possible, and I want each of them to be well-defined.
#    - There is the notion of trying to use the correlation between stocks (like I did with the MIDS 205 course) as potentially another predictive feature, but that's currently beyond the scope of what I'm trying to do here.
#    - I will, however, try the embeddings strategy and see if they can learn anything about each other.
#    - One more thing is that I could also try learning embeddings **from the tickers themselves** rather than just their sectors. That might actually provide even more support for certain tickers moving together, rather than just the correlation like I was using previously.
#      - *This might only be possible/feasible when I learn about transformers, so perhaps not yet*
# 3. For every day for my chosen tickers, I will only fetch data from 8:00am to 9:35am, primarily because I believe the 1.5 PM hours before the market opens will be the most helpful in defining what will happen to the stock. If I'm starting with trying to predict the Close price of a stock from its Open price, I will likely only use data up to and including 9:28am as my training data.
#    - The reason I'm thinking of also fetching the first 5 minutes of the Open is because those initial trading minutes are the most volatile and often the most deterministic of how a stock might perform. While I won't be using those minutes if I'm trying to predict the Close, I might want to test opening-range breakout strategies later on. If so, I might try to do some shorter-term predictions, perhaps seeing if I ever hit a certain R-level within XX minutes of entering at the 5-minute mark (or 15-min, 30-min, etc.)

# %% [markdown]
# **Update**: For now, in this notebook, I will only perform feature engineering on the day data, but my process above still stands.

# %% [markdown]
# ## Getting the tickers and their respective GICS sector, industry group, industry, and sub-industry
# To actually get the cleaned file of the tickers and their respective GICS hierarchical classification, I had to use 2 different sources:
#  - https://stockanalysis.com/stocks/
#  - https://www.msci.com/documents/1296102/29559863/GICS_structure_and_definitions_effective_close_of_March_17_2023.xlsx/e47b8086-56fd-c9d2-196f-c2054b24b1d4?t=1670964718735
#
# ...and manually merge them together (since the names of the industries/sub-industries were very different). As of now, there are still some tickers listed as "Other" or "Shell Companies", neither of which is defined under the GICS 11 overarching sectors. However, I'm going to assume that that's ok, and hopefully the model will learn that either these aren't important, or perhaps they all trend in similar directions.
#
# Both the Excel file used to manually merge the sources together, along with the csv file for just the tickers, the 4 GICS classifications, and their market cap (as of 4/16/25), are stored in the SSD.

# %%
# Getting the csv of the tickers, their GICS classes, and the market caps
tick_hier_mktcap_path = '/Volumes/T7/Tickers-and-Sector-Hierarchy/Tickers-GICS-4-Mkt-Cap.csv'
tick_hier_mktcap_df = pd.read_csv(tick_hier_mktcap_path)

tick_hier_mktcap_df.head()
# Out:
#   Ticker                             Name              Sub_Industry_Orig  \
# 0      A       Agilent Technologies, Inc.         Diagnostics & Research
# 1     AA                Alcoa Corporation                       Aluminum
# 2   AACB       Artius II Acquisition Inc.                Shell Companies
# 3   AACG            ATA Creativity Global  Education & Training Services
# 4   AACT  Ares Acquisition Corporation II                Shell Companies
#
#             Sub_Industry                          Industry  \
# 0  Health Care Equipment  Health Care Equipment & Supplies
# 1               Aluminum                   Metals & Mining
# 2        Shell Companies                   Shell Companies
# 3     Education Services     Diversified Consumer Services
# 4        Shell Companies                   Shell Companies
#
#                      Industry_Group                  Sector Market_Cap
# 0  Health Care Equipment & Services             Health Care     29.29B
# 1                         Materials               Materials      6.50B
# 2                   Shell Companies         Shell Companies    269.85M
# 3                 Consumer Services  Consumer Discretionary     30.25M
# 4                   Shell Companies         Shell Companies    700.00M

# %%
# Converting market cap to numeric
def convert_to_number(value):
    if pd.isna(value):
        return None
    value = str(value).replace(',', '').strip()

    if value.endswith('T'):
        return float(value[:-1]) * 1e12
    elif value.endswith('B'):
        return float(value[:-1]) * 1e9
    elif value.endswith('M'):
        return float(value[:-1]) * 1e6
    elif value.endswith('K'):
        return float(value[:-1]) * 1e3
    else:
        try:
            return float(value)
        except ValueError:
            return None

# Applying it on the market cap
tick_hier_mktcap_df['Market_Cap'] = tick_hier_mktcap_df['Market_Cap'].apply(convert_to_number)

tick_hier_mktcap_df
# Out:
#      Ticker                                    Name  \
# 0         A              Agilent Technologies, Inc.
# 1        AA                       Alcoa Corporation
# 2      AACB              Artius II Acquisition Inc.
# 3      AACG                   ATA Creativity Global
# 4      AACT         Ares Acquisition Corporation II
# ...     ...                                     ...
# 5476   ZVSA              ZyVersa Therapeutics, Inc.
# 5477    ZWS  Zurn Elkay Water Solutions Corporation
# 5478   ZYBT   Zhengye Biotechnology Holding Limited
# 5479   ZYME                          Zymeworks Inc.
# 5480   ZYXI                             Zynex, Inc.
#
#                              Sub_Industry_Orig                  Sub_Industry  \
# 0                       Diagnostics & Research         Health Care Equipment
# 1                                     Aluminum                      Aluminum
# 2                              Shell Companies               Shell Companies
# 3                Education & Training Services            Education Services
# 4                              Shell Companies               Shell Companies
# ...                                        ...                           ...
# 5476                             Biotechnology                 Biotechnology
# 5477            Pollution & Treatment Controls  Diversified Support Services
# 5478  Drug Manufacturers - Specialty & Generic                   Drug Retail
# 5479                             Biotechnology                 Biotechnology
# 5480                      Medical Distribution      Health Care Distributors
#
#                                     Industry  \
# 0           Health Care Equipment & Supplies
# 1                            Metals & Mining
# 2                            Shell Companies
# 3              Diversified Consumer Services
# 4                            Shell Companies
# ...                                      ...
# 5476                           Biotechnology
# 5477          Commercial Services & Supplies
# 5478  Consumer Staples Distribution & Retail
# 5479                           Biotechnology
# 5480        Health Care Providers & Services
#
#                                       Industry_Group                  Sector  \
# 0                   Health Care Equipment & Services             Health Care
# 1                                          Materials               Materials
# 2                                    Shell Companies         Shell Companies
# 3                                  Consumer Services  Consumer Discretionary
# 4                                    Shell Companies         Shell Companies
# ...                                              ...                     ...
# 5476  Pharmaceuticals, Biotechnology & Life Sciences             Health Care
# 5477             Commercial  & Professional Services             Industrials
# 5478          Consumer Staples Distribution & Retail        Consumer Staples
# 5479  Pharmaceuticals, Biotechnology & Life Sciences             Health Care
# 5480                Health Care Equipment & Services             Health Care
#
#         Market_Cap
# 0     2.929000e+10
# 1     6.500000e+09
# 2     2.698500e+08
# 3     3.025000e+07
# 4     7.000000e+08
# ...            ...
# 5476  1.850000e+06
# 5477  5.000000e+09
# 5478  3.597000e+08
# 5479  7.837800e+08
# 5480  6.438000e+07
#
# [5481 rows x 8 columns]

# %% [markdown]
# We can see from the above that we have a clean list of tickers, along with the name of their respective company, their original sub-industry, their manually corrected sub-industry, their industry, their industry group, their sector, and their market cap. We'll use the market cap to choose our tickers in the next step, but one thing we need to consider is which of the 4 GICS hierarchy levels to use. It may be wise to only use the Sector, but it also could be valuable to focus on some of the more granular classifications.
#
# Personally, since I want to use embeddings anyway, I may choose to use the finest-grain classification (sub-industry), but let's see how many unique counts of each hierarchy level we have:

# %%
# Getting the number of unique classes for each GICS hierarchy level
print("Number of unique classes for the GICS hierarchy level of:")
print(" - Sector:", tick_hier_mktcap_df['Sector'].nunique())
print(" - Industry Group:", tick_hier_mktcap_df['Industry_Group'].nunique())
print(" - Industry:", tick_hier_mktcap_df['Industry'].nunique())
print(" - Sub-Industry:", tick_hier_mktcap_df['Sub_Industry'].nunique())
# Out:
# Number of unique classes for the GICS hierarchy level of:
#  - Sector: 13
#  - Industry Group: 27
#  - Industry: 69
#  - Sub-Industry: 126

# %% [markdown]
# The number of classes seems to *roughly* double between each hierarchy, which is good to know as we move onto selecting the tickers.

# %% [markdown]
# ## Confirming the tickers above also exist in my 1-min data
# Now that we have our industries for a general set of tickers, let's make sure that the tickers in our FRD dataset are represented within this group. If there are missing tickers in the data above, then we'll likely just remove it. (The other idea would be to simply label the hierarchy levels as "Other", but we'll still be missing the market cap, which will ultimately decide what tickers we'll keep)

# %%
# Getting the paths to the SSD to the 1-min data and the day data
parquet_1min_path = '/Volumes/T7/Filtered-Cleaned-Parquet-ML'
parquet_day_path = '/Volumes/T7/Filtered-Cleaned-Parquet-1day'

# Cycling through the 1day parquet files to get the tickers
cleaned_tickers = []
for ticker_1day_parq in os.listdir(parquet_day_path):
    ticker_name = ticker_1day_parq.split('_')[0]
    cleaned_tickers.append(ticker_name)

len(cleaned_tickers)
# Out:
# 2599

# %%
# Checking to see which tickers are missing from our list
hier_mktcap_tickers = list(tick_hier_mktcap_df['Ticker'])
missing_hier_mktcap_tickers = []

print("Tickers that are not in the dataset matching each stock to their GICS hierarchy levels and market cap:")
for cleaned_ticker in cleaned_tickers:
    if cleaned_ticker not in hier_mktcap_tickers:
        print(" -", cleaned_ticker)
        missing_hier_mktcap_tickers.append(cleaned_ticker)
print("Total number of missing tickers:", len(missing_hier_mktcap_tickers))
# Out:
# Tickers that are not in the dataset matching each stock to their GICS hierarchy levels and market cap:
#  - ACCD
#  - AWF
#  - ALTR
#  - ADX
#  - AADI
#  - CLM
#  - CFB
#  - CDXC
#  - CDMO
#  - B
#  - BXMX
#  - BTZ
#  - AZPN
#  - BTT
#  - BMEZ
#  - FBMS
#  - CAF
#  - EDD
#  - AWP
#  - ATSG
#  - BSTZ
#  - DM
#  - FFIE
#  - FFC
#  - INFN
#  - IIM
#  - EXG
#  - IGD
#  - EVV
#  - IGR
#  - IFN
#  - GHY
#  - GOF
#  - GLO
#  - GGN
#  - FPF
#  - BGY
#  - MPLN
#  - ETY
#  - ETV
#  - PTVE
#  - ISD
#  - ETG
#  - LAAC
#  - KYN
#  - ITCI
#  - PHK
#  - NVRO
#  - NVG
#  - NRK
#  - NZF
#  - NMZ
#  - NAC
#  - NARI
#  - NAD
#  - PTY
#  - SUM
#  - SQ
#  - RNP
#  - BCOV
#  - HTLF
#  - SASR
#  - PML
#  - SABA
#  - RVNC
#  - WIMI
#  - RVT
#  - RQI
#  - ROIC
#  - QRTEA
#  - RA
#  - ZUO
#  - UTG
#  - ENLC
#  - YY
#  - VOXX
#  - TPX
#  - BBN
#  - NKLA
#  - SMAR
#  - PDI
#  - EMD
#  - EIM
#  - BALY
#  - NFJ
#  - NEP
#  - SILV
#  - NEA
#  - EFR
# Total number of missing tickers: 89

# %% [markdown]
# We see that there are 89 tickers that are missing in our hierarchy/mktcap list, but quickly going through them reveals that most of these companies are quite small and not as well-known. Therefore, it's likely safe to not include those stocks, and we'll move forward by getting only the tickers that do exist in our data. (Later on in the modeling notebooks, I'll probably filter even more for only the top 1,000 tickers in terms of market cap)

# %%
# Getting a new dataframe of only the tickers that exist in our 1-min data
filtered_tickers = tick_hier_mktcap_df[tick_hier_mktcap_df['Ticker'].isin(cleaned_tickers)].sort_values(by='Market_Cap', ascending=False)
filtered_tickers = filtered_tickers.reset_index(drop=True)

filtered_tickers
# Out:
#      Ticker                               Name  \
# 0      AAPL                         Apple Inc.
# 1      MSFT              Microsoft Corporation
# 2      NVDA                 NVIDIA Corporation
# 3      GOOG                      Alphabet Inc.
# 4     GOOGL                      Alphabet Inc.
# ...     ...                                ...
# 2505   GBIO                 Generation Bio Co.
# 2506   NOVA  Sunnova Energy International Inc.
# 2507    OPI     Office Properties Income Trust
# 2508   MODV                     ModivCare Inc.
# 2509     WW             WW International, Inc.
#
#                    Sub_Industry_Orig                         Sub_Industry  \
# 0               Consumer Electronics                 Consumer Electronics
# 1          Software - Infrastructure   Internet Services & Infrastructure
# 2                     Semiconductors                       Semiconductors
# 3     Internet Content & Information   Internet & Direct Marketing Retail
# 4     Internet Content & Information   Internet & Direct Marketing Retail
# ...                              ...                                  ...
# 2505                   Biotechnology                        Biotechnology
# 2506                           Solar  Semiconductor Materials & Equipment
# 2507                   REIT - Office                         Office REITs
# 2508         Medical Care Facilities                Marine Transportation
# 2509               Personal Services        Specialized Consumer Services
#
#                                       Industry  \
# 0                           Household Durables
# 1                                  IT Services
# 2     Semiconductors & Semiconductor Equipment
# 3           Internet & Direct Marketing Retail
# 4           Internet & Direct Marketing Retail
# ...                                        ...
# 2505                             Biotechnology
# 2506  Semiconductors & Semiconductor Equipment
# 2507                              Office REITs
# 2508                     Marine Transportation
# 2509             Diversified Consumer Services
#
#                                       Industry_Group                  Sector  \
# 0                        Consumer Durables & Apparel  Consumer Discretionary
# 1                                Software & Services  Information Technology
# 2           Semiconductors & Semiconductor Equipment  Information Technology
# 3       Consumer Discretionary Distribution & Retail  Consumer Discretionary
# 4       Consumer Discretionary Distribution & Retail  Consumer Discretionary
# ...                                              ...                     ...
# 2505  Pharmaceuticals, Biotechnology & Life Sciences             Health Care
# 2506        Semiconductors & Semiconductor Equipment  Information Technology
# 2507            Equity Real Estate Investment Trusts             Real Estate
# 2508                                  Transportation             Industrials
# 2509                               Consumer Services  Consumer Discretionary
#
#         Market_Cap
# 0     2.918340e+12
# 1     2.762540e+12
# 2     2.549560e+12
# 3     1.918450e+12
# 4     1.869210e+12
# ...            ...
# 2505  2.348000e+07
# 2506  2.315000e+07
# 2507  2.270000e+07
# 2508  1.606000e+07
# 2509  1.242000e+07
#
# [2510 rows x 8 columns]

# %% [markdown]
# ## Testing the day data upload speed between Macs (DO NOT EDIT)
# **Note 1**: I'm simply testing how quickly I can retrieve the day data using my new Macbook Pro compared to my old Macbook Pro.
#
# **Note 2**: I did these tests BEFORE I realized that I needed to add in the PM data up till 9:27am and 9:28am, and loading in the new data will obviously take longer in general.
#
# **Note 3**: I later updated this process one more time as I realized I wanted to use this notebook solely for feature engineering. Thus, I included all my tickers in my list, which will definitely take longer than the original 1,000 I had originally.

# %% [markdown]
# ### Using the old laptop to load the data (DO NOT EDIT)

# %%
# USING THE OLD LAPTOP AND TESTING THE SPEED (Python 3 (ipykernel))
# Getting the column names from the files (using AAPL because AAPL will always be in the data) and initializing df
AAPL_path = '/Volumes/T7/Filtered-Cleaned-Parquet-1day/AAPL_1day.parquet'
column_names_day = list(pd.read_parquet(AAPL_path).columns)
day_df = pd.DataFrame(columns=column_names_day)

# Loading the day data of the 1000 tickers in filtered_tickers into one df
for ticker in tqdm(filtered_tickers['Ticker']):

    # Reading in df
    ticker_file_name = ticker + '_1day.parquet'
    ticker_path = os.path.join(parquet_day_path, ticker_file_name)
    ticker_df = pd.read_parquet(ticker_path)

    # Setting day_df if empty
    if day_df.empty:
        day_df = ticker_df.copy()
    else:
        day_df = pd.concat([day_df, ticker_df])
    
len(day_df)
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [00:12<00:00, 78.73it/s]
# 1055000

# %% [markdown]
# It took ~12 seconds overall according to tqdm.

# %% [markdown]
# ### Using the new laptop to load the data (DO NOT EDIT)

# %%
# Using the NEW laptop and testing the speed (Python [conda env:base]
# Getting the column names from the files (using AAPL because AAPL will always be in the data) and initializing df
AAPL_path = '/Volumes/T7/Filtered-Cleaned-Parquet-1day/AAPL_1day.parquet'
column_names_day = list(pd.read_parquet(AAPL_path).columns)
day_df = pd.DataFrame(columns=column_names_day)

# Loading the day data of the 1000 tickers in filtered_tickers into one df
for ticker in tqdm(filtered_tickers['Ticker']):

    # Reading in df
    ticker_file_name = ticker + '_1day.parquet'
    ticker_path = os.path.join(parquet_day_path, ticker_file_name)
    ticker_df = pd.read_parquet(ticker_path)

    # Setting day_df if empty
    if day_df.empty:
        day_df = ticker_df.copy()
    else:
        day_df = pd.concat([day_df, ticker_df])
    
len(day_df)
# Out:
# 100%|██████████████████████████████████████| 1000/1000 [00:08<00:00, 118.59it/s]
# 1055000

# %% [markdown]
# It took ~8 seconds overall according to tqdm.

# %% [markdown]
# Overall, comparing the old laptop's data loading speed with the new laptop's speed, the new Macbook's loading speed is about 50% faster. This is a pretty small test, so it's really not saying much, but it at least gives me confidence that this new laptop is - at the very least - just as good as my old one.

# %% [markdown]
# ## Getting the minute and day data from the chosen tickers
# **Note**: Again, I will start by just getting the day data to make sure I can combine the parquet files properly and get it to work. Also, this is after I updated the Filtered-Cleaned-Parquet-1day files to include PM metrics up till 9:27am and 9:28am. Also also, this is after I updated this process another time to retrieve ALL the tickers (and not just the top 1,000).

# %%
# Getting the column names from the files (using AAPL because AAPL will always be in the data) and initializing df
AAPL_path = '/Volumes/T7/Filtered-Cleaned-Parquet-1day/AAPL_1day.parquet'
column_names_day = list(pd.read_parquet(AAPL_path).columns)
day_df = pd.DataFrame(columns=column_names_day)

# Loading the day data for all tickers in filtered_tickers into one df
for ticker in tqdm(filtered_tickers['Ticker']):

    # Reading in df
    ticker_file_name = ticker + '_1day.parquet'
    ticker_path = os.path.join(parquet_day_path, ticker_file_name)
    ticker_df = pd.read_parquet(ticker_path)

    # Setting day_df if empty
    if day_df.empty:
        day_df = ticker_df.copy()
    else:
        day_df = pd.concat([day_df, ticker_df])
    
len(day_df)
# Out:
# 100%|███████████████████████████████████████| 2510/2510 [01:27<00:00, 28.67it/s]
# 2648050

# %% [markdown]
# Overall, it took about 87 seconds to load, which is somewhat long, even with the 1,510 additional tickers I now have. My hypothesis is that the df concatenation step takes longer the larger the dfs are, which slows down the entire process towards the end.
#
# *Original (only 1,000 tickers with the 9:27am and 9:28am metrics: Overall, it took about 12 seconds to load (though I'm now using Python 3 (ipykernel) for some reason again), which is longer than before, but not too bad.*

# %% [markdown]
# ## Feature Engineering
# Now that I have the data loaded in, I can derive the features and outcome variables.

# %%
# Getting the rank (day number) of each ticker
day_df['Rank'] = day_df.groupby('Ticker').cumcount() + 1

# Creating a new data_df by joining the filtered_tickers df to the day_df
data_df = pd.merge(day_df.reset_index(), filtered_tickers, how='left', on='Ticker').set_index(day_df.index)

# Renaming the actual index and the "index" column both to "Datetime"
data_df = data_df.rename(columns={'index': 'Datetime'})

data_df.head()
# Out:
#              Datetime    Open    High     Low   Close       Volume  PM_High  \
# 2020-10-01 2020-10-01  117.70  117.72  115.83  116.80   92076075.0   118.10
# 2020-10-02 2020-10-02  112.84  115.37  112.22  113.02  116084401.0   117.08
# 2020-10-05 2020-10-05  113.92  116.65  113.55  116.54   84421170.0   114.71
# 2020-10-06 2020-10-06  115.68  116.12  112.25  113.16  132805466.0   116.79
# 2020-10-07 2020-10-07  114.64  115.55  114.13  115.05   78303638.0   114.75
#
#              PM_Low  PM_Volume Ticker  PM_High_0927  PM_Low_0927  \
# 2020-10-01  116.510  1755406.0   AAPL        118.10      116.510
# 2020-10-02  112.560  4460967.0   AAPL        117.08      112.700
# 2020-10-05  113.300  1690948.0   AAPL        114.71      113.300
# 2020-10-06  115.230  1358666.0   AAPL        116.79      115.230
# 2020-10-07  113.134  2071097.0   AAPL        114.75      113.134
#
#             PM_Close_0927  PM_Volume_0927  PM_High_0928  PM_Low_0928  \
# 2020-10-01         117.45       1690772.0        118.10      116.510
# 2020-10-02         113.00       4319384.0        117.08      112.560
# 2020-10-05         113.97       1671728.0        114.71      113.300
# 2020-10-06         116.01       1303941.0        116.79      115.230
# 2020-10-07         114.70       2032261.0        114.75      113.134
#
#             PM_Close_0928  PM_Volume_0928  Rank        Name  \
# 2020-10-01         117.68       1726947.0     1  Apple Inc.
# 2020-10-02         112.75       4389769.0     2  Apple Inc.
# 2020-10-05         113.92       1685852.0     3  Apple Inc.
# 2020-10-06         115.85       1331333.0     4  Apple Inc.
# 2020-10-07         114.60       2042679.0     5  Apple Inc.
#
#                Sub_Industry_Orig          Sub_Industry            Industry  \
# 2020-10-01  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-02  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-05  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-06  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-07  Consumer Electronics  Consumer Electronics  Household Durables
#
#                          Industry_Group                  Sector    Market_Cap
# 2020-10-01  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-02  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-05  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-06  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-07  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12

# %% [markdown]
# Obtaining the outcome variables (though will likely only use Close_Open_Diff_Ternary at the end):

# %%
# Getting difference between close price and open price (outcome variables)
data_df["Close_Open_Diff"] = data_df["Close"] - data_df["Open"]
data_df["Close_Open_Diff_Perc"] = (data_df["Close"] - data_df["Open"]) / data_df["Open"] * 100

# Getting binary classification for whether a stock ended positive (1) or negative/zero (0)
data_df["Close_Open_Diff_Binary"] = data_df["Close_Open_Diff"] > 0

# Getting ternary classification for whether a stock ended positive (2), negative (0), or not much change (1)
close_open_conditions = [
    data_df['Close_Open_Diff_Perc'] > 0.5,       # Close price was at least 0.5% higher than Open price
    (data_df['Close_Open_Diff_Perc'] >= -0.5) &  # Close price was between -0.5% and 0.5% of Open price
        (data_df['Close_Open_Diff_Perc'] <= 0.5),
    data_df['Close_Open_Diff_Perc'] < -0.5       # Close price was at least 0.5% lower than Open price
]
close_open_choices = [2, 1, 0]  # Defining choices corresponding to conditions
data_df['Close_Open_Diff_Ternary'] = np.select(close_open_conditions, close_open_choices)  # Applying conditions

data_df.head()
# Out:
#              Datetime    Open    High     Low   Close       Volume  PM_High  \
# 2020-10-01 2020-10-01  117.70  117.72  115.83  116.80   92076075.0   118.10
# 2020-10-02 2020-10-02  112.84  115.37  112.22  113.02  116084401.0   117.08
# 2020-10-05 2020-10-05  113.92  116.65  113.55  116.54   84421170.0   114.71
# 2020-10-06 2020-10-06  115.68  116.12  112.25  113.16  132805466.0   116.79
# 2020-10-07 2020-10-07  114.64  115.55  114.13  115.05   78303638.0   114.75
#
#              PM_Low  PM_Volume Ticker  PM_High_0927  PM_Low_0927  \
# 2020-10-01  116.510  1755406.0   AAPL        118.10      116.510
# 2020-10-02  112.560  4460967.0   AAPL        117.08      112.700
# 2020-10-05  113.300  1690948.0   AAPL        114.71      113.300
# 2020-10-06  115.230  1358666.0   AAPL        116.79      115.230
# 2020-10-07  113.134  2071097.0   AAPL        114.75      113.134
#
#             PM_Close_0927  PM_Volume_0927  PM_High_0928  PM_Low_0928  \
# 2020-10-01         117.45       1690772.0        118.10      116.510
# 2020-10-02         113.00       4319384.0        117.08      112.560
# 2020-10-05         113.97       1671728.0        114.71      113.300
# 2020-10-06         116.01       1303941.0        116.79      115.230
# 2020-10-07         114.70       2032261.0        114.75      113.134
#
#             PM_Close_0928  PM_Volume_0928  Rank        Name  \
# 2020-10-01         117.68       1726947.0     1  Apple Inc.
# 2020-10-02         112.75       4389769.0     2  Apple Inc.
# 2020-10-05         113.92       1685852.0     3  Apple Inc.
# 2020-10-06         115.85       1331333.0     4  Apple Inc.
# 2020-10-07         114.60       2042679.0     5  Apple Inc.
#
#                Sub_Industry_Orig          Sub_Industry            Industry  \
# 2020-10-01  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-02  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-05  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-06  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-07  Consumer Electronics  Consumer Electronics  Household Durables
#
#                          Industry_Group                  Sector    Market_Cap  \
# 2020-10-01  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-02  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-05  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-06  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-07  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
#
#             Close_Open_Diff  Close_Open_Diff_Perc  Close_Open_Diff_Binary  \
# 2020-10-01            -0.90             -0.764656                   False
# 2020-10-02             0.18              0.159518                    True
# 2020-10-05             2.62              2.299860                    True
# 2020-10-06            -2.52             -2.178423                   False
# 2020-10-07             0.41              0.357641                    True
#
#             Close_Open_Diff_Ternary
# 2020-10-01                        0
# 2020-10-02                        1
# 2020-10-05                        2
# 2020-10-06                        0
# 2020-10-07                        1

# %% [markdown]
# Getting the previous day OHLCV metrics along with the previous day PM HLCV metrics up till 9:27am and 9:28am:

# %%
# Getting previous day OHLCV metrics
data_df["PDO"] = data_df["Open"].shift(1)
data_df["PDH"] = data_df["High"].shift(1)
data_df["PDL"] = data_df["Low"].shift(1)
data_df["PDC"] = data_df["Close"].shift(1)
data_df["PDV"] = data_df["Volume"].shift(1)

# Getting previous day PM Volume metrics up till 9:27am and 9:28am
data_df["PD_PM_V_0927"] = data_df["PM_Volume_0927"].shift(1)
data_df["PD_PM_V_0928"] = data_df["PM_Volume_0928"].shift(1)

# %% [markdown]
# In my original project, I obtained the gap features using the **Open** price. However, to make this more realistic, I will use the Close price at 9:28am as a substitute for the Open. The reasons for doing so are as follow:
# 1. The Close price at 9:28am is only 1 minute away from the Open price, and even though a lot can happen in that last minute, this will need to be good enough.
# 2. One minute should hopefully be enough time for me to get the updated minute data from (probably) IBKR, run inference using my ML model, and prepare the trades accordingly at the Open.

# %%
# Getting the gap features from 9:28 Close compared to the PDC
data_df["Gap_from_PDC"] = (data_df["PM_Close_0928"] - data_df["PDC"]) / data_df["PDC"]
gap_from_PDC_threshold = 0.02  # 2%
data_df["Gap_Binary_Threshold"] = abs(data_df["Gap_from_PDC"]) > gap_from_PDC_threshold

# Getting daily range gap up features
data_df["Daily_Range_Gap_Up"] = (data_df["PM_Close_0928"] - data_df["PDH"]) / data_df["PDH"]
data_df["Daily_Range_Gap_Up"] = data_df["Daily_Range_Gap_Up"].clip(lower = 0)
data_df["DR_Gap_Up_Binary"] = data_df["Daily_Range_Gap_Up"] > 0

# Getting daily range gap down features
data_df["Daily_Range_Gap_Down"] = (data_df["PM_Close_0928"] - data_df["PDL"]) / data_df["PDL"]
data_df["Daily_Range_Gap_Down"] = data_df["Daily_Range_Gap_Down"].clip(upper = 0)
data_df["DR_Gap_Down_Binary"] = data_df["Daily_Range_Gap_Down"] < 0

# Getting previous 14-day average PM volume up till 9:28am (i.e., using PD_PM_V_0928)
avg_vol_window = 14
data_df["Avg_PM_Vol_Prev_14D"] = data_df["PD_PM_V_0928"].rolling(window=avg_vol_window).mean()

# Comparing current PM volume to average PM volume over the past XX days
data_df["PM_Vol_Change"] = (data_df["PM_Volume_0928"] - data_df["Avg_PM_Vol_Prev_14D"]) / data_df["Avg_PM_Vol_Prev_14D"]

# Setting the first 14-day PM volume averages and previous volume change amounts of every ticker to np.nan
data_df.loc[data_df["Rank"] < 15, ["Avg_PM_Vol_Prev_14D", "PM_Vol_Change"]] = np.nan

display(data_df[10:20])
display(data_df.shape)
# Out:
#              Datetime    Open     High     Low    Close       Volume  PM_High  \
# 2020-10-15 2020-10-15  118.75  121.200  118.15  120.745   92741440.0   121.49
# 2020-10-16 2020-10-16  121.25  121.548  118.81  118.960   92366893.0   122.11
# 2020-10-19 2020-10-19  119.96  120.419  115.66  116.000  100858537.0   121.05
# 2020-10-20 2020-10-20  116.23  118.980  115.63  117.500  103813586.0   118.35
# 2020-10-21 2020-10-21  116.63  118.705  116.45  116.860   73640108.0   117.94
# 2020-10-22 2020-10-22  117.41  118.040  114.59  115.774   86318174.0   117.58
# 2020-10-23 2020-10-23  116.38  116.550  114.28  115.050   68258650.0   116.65
# 2020-10-26 2020-10-26  114.01  116.550  112.88  115.060   90955903.0   115.32
# 2020-10-27 2020-10-27  115.42  117.280  114.54  116.530   76025170.0   116.00
# 2020-10-28 2020-10-28  115.04  115.430  111.10  111.150  108210209.0   116.89
#
#             PM_Low  PM_Volume Ticker  PM_High_0927  PM_Low_0927  \
# 2020-10-15  117.25  2945665.0   AAPL        121.49       117.25
# 2020-10-16  120.65  1883037.0   AAPL        122.11       120.65
# 2020-10-19  119.02  1966792.0   AAPL        121.05       119.02
# 2020-10-20  116.12  1674408.0   AAPL        118.35       116.21
# 2020-10-21  116.50  1272131.0   AAPL        117.94       116.50
# 2020-10-22  116.00  1522067.0   AAPL        117.58       116.00
# 2020-10-23  115.88   790808.0   AAPL        116.65       115.88
# 2020-10-26  113.31  1556823.0   AAPL        115.32       113.31
# 2020-10-27  115.00   877134.0   AAPL        116.00       115.00
# 2020-10-28  114.51  1361530.0   AAPL        116.89       114.51
#
#             PM_Close_0927  PM_Volume_0927  PM_High_0928  PM_Low_0928  \
# 2020-10-15         118.88       2876720.0        121.49       117.25
# 2020-10-16         121.75       1571778.0        122.11       120.65
# 2020-10-19         120.01       1926163.0        121.05       119.02
# 2020-10-20         116.24       1617201.0        118.35       116.12
# 2020-10-21         117.27       1015301.0        117.94       116.50
# 2020-10-22         117.45       1487131.0        117.58       116.00
# 2020-10-23         116.38        759476.0        116.65       115.88
# 2020-10-26         114.05       1470021.0        115.32       113.31
# 2020-10-27         115.38        844939.0        116.00       115.00
# 2020-10-28         114.97       1323057.0        116.89       114.51
#
#             PM_Close_0928  PM_Volume_0928  Rank        Name  \
# 2020-10-15         118.80       2906007.0    11  Apple Inc.
# 2020-10-16         121.85       1685166.0    12  Apple Inc.
# 2020-10-19         119.97       1949307.0    13  Apple Inc.
# 2020-10-20         116.24       1648903.0    14  Apple Inc.
# 2020-10-21         116.75       1201839.0    15  Apple Inc.
# 2020-10-22         117.45       1502827.0    16  Apple Inc.
# 2020-10-23         116.33        773781.0    17  Apple Inc.
# 2020-10-26         114.00       1525760.0    18  Apple Inc.
# 2020-10-27         115.50        865306.0    19  Apple Inc.
# 2020-10-28         114.99       1340196.0    20  Apple Inc.
#
#                Sub_Industry_Orig          Sub_Industry            Industry  \
# 2020-10-15  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-16  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-19  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-20  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-21  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-22  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-23  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-26  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-27  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-28  Consumer Electronics  Consumer Electronics  Household Durables
#
#                          Industry_Group                  Sector    Market_Cap  \
# 2020-10-15  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-16  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-19  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-20  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-21  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-22  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-23  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-26  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-27  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-28  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
#
#             Close_Open_Diff  Close_Open_Diff_Perc  Close_Open_Diff_Binary  \
# 2020-10-15            1.995              1.680000                    True
# 2020-10-16           -2.290             -1.888660                   False
# 2020-10-19           -3.960             -3.301100                   False
# 2020-10-20            1.270              1.092661                    True
# 2020-10-21            0.230              0.197205                    True
# 2020-10-22           -1.636             -1.393408                   False
# 2020-10-23           -1.330             -1.142808                   False
# 2020-10-26            1.050              0.920972                    True
# 2020-10-27            1.110              0.961705                    True
# 2020-10-28           -3.890             -3.381433                   False
#
#             Close_Open_Diff_Ternary     PDO      PDH     PDL      PDC  \
# 2020-10-15                        2  120.99  123.030  119.62  121.290
# 2020-10-16                        0  118.75  121.200  118.15  120.745
# 2020-10-19                        0  121.25  121.548  118.81  118.960
# 2020-10-20                        2  119.96  120.419  115.66  116.000
# 2020-10-21                        1  116.23  118.980  115.63  117.500
# 2020-10-22                        0  116.63  118.705  116.45  116.860
# 2020-10-23                        0  117.41  118.040  114.59  115.774
# 2020-10-26                        2  116.38  116.550  114.28  115.050
# 2020-10-27                        2  114.01  116.550  112.88  115.060
# 2020-10-28                        0  115.42  117.280  114.54  116.530
#
#                     PDV  PD_PM_V_0927  PD_PM_V_0928  Gap_from_PDC  \
# 2020-10-15  128874678.0     2134894.0     2152679.0     -0.020529
# 2020-10-16   92741440.0     2876720.0     2906007.0      0.009152
# 2020-10-19   92366893.0     1571778.0     1685166.0      0.008490
# 2020-10-20  100858537.0     1926163.0     1949307.0      0.002069
# 2020-10-21  103813586.0     1617201.0     1648903.0     -0.006383
# 2020-10-22   73640108.0     1015301.0     1201839.0      0.005049
# 2020-10-23   86318174.0     1487131.0     1502827.0      0.004802
# 2020-10-26   68258650.0      759476.0      773781.0     -0.009126
# 2020-10-27   90955903.0     1470021.0     1525760.0      0.003824
# 2020-10-28   76025170.0      844939.0      865306.0     -0.013215
#
#             Gap_Binary_Threshold  Daily_Range_Gap_Up  DR_Gap_Up_Binary  \
# 2020-10-15                  True            0.000000             False
# 2020-10-16                 False            0.005363              True
# 2020-10-19                 False            0.000000             False
# 2020-10-20                 False            0.000000             False
# 2020-10-21                 False            0.000000             False
# 2020-10-22                 False            0.000000             False
# 2020-10-23                 False            0.000000             False
# 2020-10-26                 False            0.000000             False
# 2020-10-27                 False            0.000000             False
# 2020-10-28                 False            0.000000             False
#
#             Daily_Range_Gap_Down  DR_Gap_Down_Binary  Avg_PM_Vol_Prev_14D  \
# 2020-10-15             -0.006855                True                  NaN
# 2020-10-16              0.000000               False                  NaN
# 2020-10-19              0.000000               False                  NaN
# 2020-10-20              0.000000               False                  NaN
# 2020-10-21              0.000000               False         2.443894e+06
# 2020-10-22              0.000000               False         2.406386e+06
# 2020-10-23              0.000000               False         2.200176e+06
# 2020-10-26             -0.002450                True         2.135028e+06
# 2020-10-27              0.000000               False         2.148915e+06
# 2020-10-28              0.000000               False         2.064817e+06
#
#             PM_Vol_Change
# 2020-10-15            NaN
# 2020-10-16            NaN
# 2020-10-19            NaN
# 2020-10-20            NaN
# 2020-10-21      -0.508228
# 2020-10-22      -0.375484
# 2020-10-23      -0.648309
# 2020-10-26      -0.285368
# 2020-10-27      -0.597329
# 2020-10-28      -0.350937
# (2648050, 45)

# %% [markdown]
# Getting the features for the SMA & EMA of the past XXX periods, the real-time RSI, and the real-time ATR & NATR:

# %%
# SMA and EMA for the past XXX periods
data_df["SMA_Prev_14"] = data_df["PDC"].rolling(window=14).mean()
data_df["SMA_Prev_50"] = data_df["PDC"].rolling(window=50).mean()
data_df["EMA_Prev_9"] = data_df["PDC"].ewm(span=9, adjust=False).mean()
data_df["EMA_Prev_20"] = data_df["PDC"].ewm(span=20, adjust=False).mean()

# Defining a function to calculate the RSI_14 based on the previous 13-day Close prices and the current day's 9:28am Close price
def calculate_real_time_RSI(df, period=14):
    # Defining the pure Close change amounts
    Close_Chg_Amt = df["Close"] - df["PDC"]
    Close_Gain_Amt = Close_Chg_Amt.clip(lower = 0)
    Close_Loss_Amt = Close_Chg_Amt.clip(upper = 0)

    # Defining the change amounts from the Close at 9:28am against the PDC
    Curr_Chg_Amt_0928 = df["PM_Close_0928"] - df["PDC"]
    Curr_Gain_Amt_0928 = Curr_Chg_Amt_0928.clip(lower = 0)
    Curr_Loss_Amt_0928 = Curr_Chg_Amt_0928.clip(upper = 0)

    # Calculating avg gain and loss using the previous 13 gain/loss amts (shift(1)) and the gain/loss amt at 9:28am compared to the PDC
    Avg_Gain = (Close_Gain_Amt.shift(1).rolling(window=(period-1)).sum() + Curr_Gain_Amt_0928) / period
    Avg_Loss = (Close_Loss_Amt.shift(1).rolling(window=(period-1)).sum() + Curr_Loss_Amt_0928) / period

    # Getting relative strength (RS) and relative strength index (RSI)
    RS = -1 * Avg_Gain / Avg_Loss  # It's ok if Avg_Loss is 0 and we get -inf; the final RSI calculation will just make that 0
    RSI = 100 - (100 / (1 + RS))
    
    return RSI

# Defining a function to calculate ATR_14 using the 9:28am period
def calculate_ATR(df, period=14):
    # Defining the previous range and ATR values
    Prev_Range = df["PDH"] - df["PDL"]
    Prev_ATR = Prev_Range.rolling(window=(period-1)).mean()

    # Calculating True Range and ultimately getting the ATR_14
    H_sub_L = df["PM_High_0928"] - df["PM_Low_0928"]
    H_sub_Cp = abs(df["PM_High_0928"] - df["PDC"])
    L_sub_Cp = abs(df["PM_Low_0928"] - df["PDC"])
    True_Range = pd.concat([H_sub_L, H_sub_Cp, L_sub_Cp], axis=1).max(axis=1)
    ATR = ((Prev_ATR * (period - 1)) + True_Range) / period

    return ATR

# Calculating RSI_14, ATR_14, and NATR_14 (all using the 9:28am period)
data_df["RSI_14"] = calculate_real_time_RSI(data_df, 14)
data_df["ATR_14"] = calculate_ATR(data_df, 14)
data_df["NATR_14"] = (data_df["ATR_14"] / data_df["PDC"]) * 100

# Setting 9, 14, 20, and 50 day metrics to np.nan:
data_df.loc[data_df["Rank"] <= 9, ["EMA_Prev_9"]] = np.nan
data_df.loc[data_df["Rank"] <= 14, ["SMA_Prev_14", "RSI_14", "ATR_14", "NATR_14"]] = np.nan
data_df.loc[data_df["Rank"] <= 20, ["EMA_Prev_20"]] = np.nan
data_df.loc[data_df["Rank"] <= 50, ["SMA_Prev_50"]] = np.nan

display(data_df.shape)
# Out:
# (2648050, 52)

# %% [markdown]
# Obtaining the Bollinger Band features and volatility indicator based on STD from the SMA_20:

# %%
# Obtaining the center, upper, and lower Bollinger Bands based on the previous Close prices and the Close price at 9:28am, along with the
# number of standard deviations away from the SMA_20 the Close price at 9:28am is
def calculate_bbands(df, period=20, std_num=2):
    # Getting the rolling sum and the rolling sum of squares of the previous 19 PDCs
    PDC_Rolling_Sum = df["PDC"].rolling(window=(period-1), min_periods=(period-1)).sum()
    PDC_Rolling_Sum_Squares = df["PDC"].pow(2).rolling(window=(period-1), min_periods=(period-1)).sum()

    # Getting the combined sums with the Close price at 9:28am
    Combined_Sum = PDC_Rolling_Sum + df["PM_Close_0928"]
    Combined_Sum_Squares = PDC_Rolling_Sum_Squares + df["PM_Close_0928"] ** 2

    # Getting the std using the formula: sqrt((Σx^2 - (Σx)^2 / n) / (n-1))
    Combined_STD = np.sqrt((Combined_Sum_Squares - (Combined_Sum ** 2) / period) / (period - 1))

    # Getting the center Bollinger Band, which is effectively the average of the previous 19 PDCs plus the Close at 9:28am (i.e., SMA_20)
    SMA_20 = Combined_Sum / period

    # Getting the upper and lower Bollinger Bands based on 2 stds above and below the SMA_20
    Upper_BBand = SMA_20 + 2 * Combined_STD
    Lower_BBand = SMA_20 - 2 * Combined_STD

    # Getting the number of standard deviations away from the SMA_20 at 9:28am
    Num_STD_from_SMA_20 = (df["PM_Close_0928"] - SMA_20) / Combined_STD

    return SMA_20, Upper_BBand, Lower_BBand, Num_STD_from_SMA_20

# Setting the SMA_20 at 9:28am, the upper and lower Bollinger Bands, and the num stds away from the SMA_20 in the original data_df
SMA_20, Upper_BBand, Lower_BBand, Num_STD_from_SMA_20 = calculate_bbands(data_df)
data_df["SMA_20"] = SMA_20
data_df["Upper_BBand"] = Upper_BBand
data_df["Lower_BBand"] = Lower_BBand
data_df["Num_STD_from_SMA_20"] = Num_STD_from_SMA_20

display(data_df[18:22])
display(data_df.shape)
# Out:
#              Datetime    Open    High     Low   Close       Volume  PM_High  \
# 2020-10-27 2020-10-27  115.42  117.28  114.54  116.53   76025170.0   116.00
# 2020-10-28 2020-10-28  115.04  115.43  111.10  111.15  108210209.0   116.89
# 2020-10-29 2020-10-29  112.37  116.93  112.20  114.52  102297860.0   113.69
# 2020-10-30 2020-10-30  111.03  111.99  107.72  108.90  151657835.0   111.95
#
#             PM_Low  PM_Volume Ticker  PM_High_0927  PM_Low_0927  \
# 2020-10-27  115.00   877134.0   AAPL        116.00       115.00
# 2020-10-28  114.51  1361530.0   AAPL        116.89       114.51
# 2020-10-29  111.70  2178031.0   AAPL        113.69       111.70
# 2020-10-30  108.70  2798215.0   AAPL        111.40       108.70
#
#             PM_Close_0927  PM_Volume_0927  PM_High_0928  PM_Low_0928  \
# 2020-10-27         115.38        844939.0        116.00       115.00
# 2020-10-28         114.97       1323057.0        116.89       114.51
# 2020-10-29         112.44       2153965.0        113.69       111.70
# 2020-10-30         110.96       2733096.0        111.95       108.70
#
#             PM_Close_0928  PM_Volume_0928  Rank        Name  \
# 2020-10-27         115.50        865306.0    19  Apple Inc.
# 2020-10-28         114.99       1340196.0    20  Apple Inc.
# 2020-10-29         112.44       2161444.0    21  Apple Inc.
# 2020-10-30         111.01       2775072.0    22  Apple Inc.
#
#                Sub_Industry_Orig          Sub_Industry            Industry  \
# 2020-10-27  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-28  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-29  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-30  Consumer Electronics  Consumer Electronics  Household Durables
#
#                          Industry_Group                  Sector    Market_Cap  \
# 2020-10-27  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-28  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-29  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-30  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
#
#             Close_Open_Diff  Close_Open_Diff_Perc  Close_Open_Diff_Binary  \
# 2020-10-27             1.11              0.961705                    True
# 2020-10-28            -3.89             -3.381433                   False
# 2020-10-29             2.15              1.913322                    True
# 2020-10-30            -2.13             -1.918400                   False
#
#             Close_Open_Diff_Ternary     PDO     PDH     PDL     PDC  \
# 2020-10-27                        2  114.01  116.55  112.88  115.06
# 2020-10-28                        0  115.42  117.28  114.54  116.53
# 2020-10-29                        2  115.04  115.43  111.10  111.15
# 2020-10-30                        0  112.37  116.93  112.20  114.52
#
#                     PDV  PD_PM_V_0927  PD_PM_V_0928  Gap_from_PDC  \
# 2020-10-27   90955903.0     1470021.0     1525760.0      0.003824
# 2020-10-28   76025170.0      844939.0      865306.0     -0.013215
# 2020-10-29  108210209.0     1323057.0     1340196.0      0.011606
# 2020-10-30  102297860.0     2153965.0     2161444.0     -0.030650
#
#             Gap_Binary_Threshold  Daily_Range_Gap_Up  DR_Gap_Up_Binary  \
# 2020-10-27                 False                 0.0             False
# 2020-10-28                 False                 0.0             False
# 2020-10-29                 False                 0.0             False
# 2020-10-30                  True                 0.0             False
#
#             Daily_Range_Gap_Down  DR_Gap_Down_Binary  Avg_PM_Vol_Prev_14D  \
# 2020-10-27              0.000000               False         2.148915e+06
# 2020-10-28              0.000000               False         2.064817e+06
# 2020-10-29              0.000000               False         2.055168e+06
# 2020-10-30             -0.010606                True         2.138593e+06
#
#             PM_Vol_Change  SMA_Prev_14  SMA_Prev_50  EMA_Prev_9  EMA_Prev_20  \
# 2020-10-27      -0.597329   117.836357          NaN  116.662398          NaN
# 2020-10-28      -0.350937   117.942071          NaN  116.635919          NaN
# 2020-10-29       0.051712   117.669214          NaN  115.538735   116.462219
# 2020-10-30       0.297616   117.493500          NaN  115.334988   116.277246
#
#                RSI_14    ATR_14   NATR_14     SMA_20  Upper_BBand  \
# 2020-10-27  50.985545  3.248429  2.823247        NaN          NaN
# 2020-10-28  50.039494  3.413429  2.929227  117.03745   122.860503
# 2020-10-29  42.018284  3.585571  3.225885  116.62745   123.264680
# 2020-10-30  24.783753  3.736571  3.262811  116.63095   123.354034
#
#             Lower_BBand  Num_STD_from_SMA_20
# 2020-10-27          NaN                  NaN
# 2020-10-28   111.214397            -0.703222
# 2020-10-29   109.990220            -1.261806
# 2020-10-30   109.907866            -1.672134
# (2648050, 56)

# %% [markdown]
# Obtaining the On Balance Volume and Stochastic Oscillator features:

# %%
# Getting the previous positive or negative volumes based on PDC minus the PDC of the previous CS
data_df["Close_Chg_Amt"] = data_df["Close"] - data_df["PDC"]
data_df["Prev_Pos_Neg_Vol"] = np.where(data_df["Close_Chg_Amt"].shift(1) > 0, data_df["PDV"],
                                       np.where(data_df["Close_Chg_Amt"].shift(1) < 0, data_df["PDV"] * -1, 0))
data_df.loc[data_df["Rank"] <= 2, ["Prev_Pos_Neg_Vol"]] = 0.0  # Setting Prev_Pos_Neg_Vol for first two days to 0 to calibrate properly

# Getting the previous On Balance Volume (OBV) by ticker to try predicting larger trends in price movements
data_df["Prev_OBV"] = data_df.groupby("Ticker")["Prev_Pos_Neg_Vol"].cumsum()

# Defining a function to calculate the real-time %K and %D in the stochastic oscillator formula (assuming k_period = 14 and d_period = 3)
def calculate_stochastic_oscillator(df, k_period=14, d_period=3):
    """
    Note: To account for the real-time data we get at 9:28am, I had to do the calculations a bit differently. To quickly explain:
      1. I calculate the %K based on the High and Low prices of the 13 previous days along with the High and Low prices of the current
      day up till 9:28am. This effectively gives me my 14 periods, and my "current closing price" is set to the Close price 9:28am.
          - E.g., If I'm on Day 14, I use the H/L of days 1-13 along with H/L of Day 14 up till 9:28am to get my real-time %K.
      
      2. I calculate the %D based on the previous two "true" %K values along with the "real-time" %K. More specifically, the previous 
      "true" %K values are calculated from 1) the rolling average of the previous 14 Close prices, and 2) the rolling average of the
      previous 14 Close prices BEFORE the PDC. I then add those two values along with the real-time %K, then divide that total by my
      d_period (3), to ultimately get my real-time %D.
          - E.g., If I'm on Day 16, I can get my "true" %K values (calculated from the Close prices of the last day) from 1) days 1-14
          and 2) days 2-15, add those with my real-time %K I calculated above, and then divide by 3 to get my real-time %D.
    """
    # Copying the df and only the columns we need
    df_so = df.copy()
    df_so = df_so[["PDH", "PDL", "PDC", "PM_High_0928", "PM_Low_0928", "PM_Close_0928"]]
    
    # Getting the lowest lows and the highest highs of the past 13 periods plus the low/high at 9:28am to get real-time %K
    df_so["PDL_Min_13"] = df_so["PDL"].rolling(window=(k_period-1)).min()
    df_so["PDH_Max_13"] = df_so["PDH"].rolling(window=(k_period-1)).max()
    df_so["Low_Min_RT"] = df_so[["PDL_Min_13", "PM_Low_0928"]].min(axis=1)  # Lowest minimum in real-time (9:28am)
    df_so["High_Max_RT"] = df_so[["PDH_Max_13", "PM_High_0928"]].max(axis=1)  # Highest maximum in real-time (9:28am)
    df_so["Sto_Osc_K_RT"] = (df_so["PM_Close_0928"] - df_so["Low_Min_RT"]) / (df_so["High_Max_RT"] - df_so["Low_Min_RT"]) * 100

    # Getting the previous %K, ONLY for the purposes of getting the real-time %D afterward
    df_so["PDL_Min_14"] = df_so["PDL"].rolling(window=(k_period)).min()
    df_so["PDH_Max_14"] = df_so["PDH"].rolling(window=(k_period)).max()
    df_so["Prev_K"] = (df_so["PDC"] - df_so["PDL_Min_14"]) / (df_so["PDH_Max_14"] - df_so["PDL_Min_14"]) * 100    
    df_so["Sto_Osc_D_RT"] = (df_so["Prev_K"].rolling(window=(d_period-1)).sum() + df_so["Sto_Osc_K_RT"]) / d_period

    return df_so["Sto_Osc_K_RT"], df_so["Sto_Osc_D_RT"]

# Getting the real-time %K and %D into the original df
Sto_Osc_K_RT, Sto_Osc_D_RT = calculate_stochastic_oscillator(data_df)
data_df["Sto_Osc_K_RT"] = Sto_Osc_K_RT
data_df["Sto_Osc_D_RT"] = Sto_Osc_D_RT
data_df.loc[data_df["Rank"] <= 13, ["Sto_Osc_K_RT"]] = np.nan  # Making sure first 13 %K doesn't exist
data_df.loc[data_df["Rank"] <= 15, ["Sto_Osc_D_RT"]] = np.nan  # Making sure first 15 %D doesn't exist

display(data_df[12:18])
display(data_df.shape)
# Out:
#              Datetime    Open     High     Low    Close       Volume  PM_High  \
# 2020-10-19 2020-10-19  119.96  120.419  115.66  116.000  100858537.0   121.05
# 2020-10-20 2020-10-20  116.23  118.980  115.63  117.500  103813586.0   118.35
# 2020-10-21 2020-10-21  116.63  118.705  116.45  116.860   73640108.0   117.94
# 2020-10-22 2020-10-22  117.41  118.040  114.59  115.774   86318174.0   117.58
# 2020-10-23 2020-10-23  116.38  116.550  114.28  115.050   68258650.0   116.65
# 2020-10-26 2020-10-26  114.01  116.550  112.88  115.060   90955903.0   115.32
#
#             PM_Low  PM_Volume Ticker  PM_High_0927  PM_Low_0927  \
# 2020-10-19  119.02  1966792.0   AAPL        121.05       119.02
# 2020-10-20  116.12  1674408.0   AAPL        118.35       116.21
# 2020-10-21  116.50  1272131.0   AAPL        117.94       116.50
# 2020-10-22  116.00  1522067.0   AAPL        117.58       116.00
# 2020-10-23  115.88   790808.0   AAPL        116.65       115.88
# 2020-10-26  113.31  1556823.0   AAPL        115.32       113.31
#
#             PM_Close_0927  PM_Volume_0927  PM_High_0928  PM_Low_0928  \
# 2020-10-19         120.01       1926163.0        121.05       119.02
# 2020-10-20         116.24       1617201.0        118.35       116.12
# 2020-10-21         117.27       1015301.0        117.94       116.50
# 2020-10-22         117.45       1487131.0        117.58       116.00
# 2020-10-23         116.38        759476.0        116.65       115.88
# 2020-10-26         114.05       1470021.0        115.32       113.31
#
#             PM_Close_0928  PM_Volume_0928  Rank        Name  \
# 2020-10-19         119.97       1949307.0    13  Apple Inc.
# 2020-10-20         116.24       1648903.0    14  Apple Inc.
# 2020-10-21         116.75       1201839.0    15  Apple Inc.
# 2020-10-22         117.45       1502827.0    16  Apple Inc.
# 2020-10-23         116.33        773781.0    17  Apple Inc.
# 2020-10-26         114.00       1525760.0    18  Apple Inc.
#
#                Sub_Industry_Orig          Sub_Industry            Industry  \
# 2020-10-19  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-20  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-21  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-22  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-23  Consumer Electronics  Consumer Electronics  Household Durables
# 2020-10-26  Consumer Electronics  Consumer Electronics  Household Durables
#
#                          Industry_Group                  Sector    Market_Cap  \
# 2020-10-19  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-20  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-21  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-22  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-23  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
# 2020-10-26  Consumer Durables & Apparel  Consumer Discretionary  2.918340e+12
#
#             Close_Open_Diff  Close_Open_Diff_Perc  Close_Open_Diff_Binary  \
# 2020-10-19           -3.960             -3.301100                   False
# 2020-10-20            1.270              1.092661                    True
# 2020-10-21            0.230              0.197205                    True
# 2020-10-22           -1.636             -1.393408                   False
# 2020-10-23           -1.330             -1.142808                   False
# 2020-10-26            1.050              0.920972                    True
#
#             Close_Open_Diff_Ternary     PDO      PDH     PDL      PDC  \
# 2020-10-19                        0  121.25  121.548  118.81  118.960
# 2020-10-20                        2  119.96  120.419  115.66  116.000
# 2020-10-21                        1  116.23  118.980  115.63  117.500
# 2020-10-22                        0  116.63  118.705  116.45  116.860
# 2020-10-23                        0  117.41  118.040  114.59  115.774
# 2020-10-26                        2  116.38  116.550  114.28  115.050
#
#                     PDV  PD_PM_V_0927  PD_PM_V_0928  Gap_from_PDC  \
# 2020-10-19   92366893.0     1571778.0     1685166.0      0.008490
# 2020-10-20  100858537.0     1926163.0     1949307.0      0.002069
# 2020-10-21  103813586.0     1617201.0     1648903.0     -0.006383
# 2020-10-22   73640108.0     1015301.0     1201839.0      0.005049
# 2020-10-23   86318174.0     1487131.0     1502827.0      0.004802
# 2020-10-26   68258650.0      759476.0      773781.0     -0.009126
#
#             Gap_Binary_Threshold  Daily_Range_Gap_Up  DR_Gap_Up_Binary  \
# 2020-10-19                 False                 0.0             False
# 2020-10-20                 False                 0.0             False
# 2020-10-21                 False                 0.0             False
# 2020-10-22                 False                 0.0             False
# 2020-10-23                 False                 0.0             False
# 2020-10-26                 False                 0.0             False
#
#             Daily_Range_Gap_Down  DR_Gap_Down_Binary  Avg_PM_Vol_Prev_14D  \
# 2020-10-19               0.00000               False                  NaN
# 2020-10-20               0.00000               False                  NaN
# 2020-10-21               0.00000               False         2.443894e+06
# 2020-10-22               0.00000               False         2.406386e+06
# 2020-10-23               0.00000               False         2.200176e+06
# 2020-10-26              -0.00245                True         2.135028e+06
#
#             PM_Vol_Change  SMA_Prev_14  SMA_Prev_50  EMA_Prev_9  EMA_Prev_20  \
# 2020-10-19            NaN          NaN          NaN  119.129510          NaN
# 2020-10-20            NaN          NaN          NaN  118.503608          NaN
# 2020-10-21      -0.508228   117.606071          NaN  118.302886          NaN
# 2020-10-22      -0.375484   117.610357          NaN  118.014309          NaN
# 2020-10-23      -0.648309   117.807071          NaN  117.566247          NaN
# 2020-10-26      -0.285368   117.700643          NaN  117.062998          NaN
#
#                RSI_14    ATR_14   NATR_14  SMA_20  Upper_BBand  Lower_BBand  \
# 2020-10-19        NaN       NaN       NaN     NaN          NaN          NaN
# 2020-10-20        NaN       NaN       NaN     NaN          NaN          NaN
# 2020-10-21  49.924812  3.272357  2.784985     NaN          NaN          NaN
# 2020-10-22  57.395659  3.218429  2.754089     NaN          NaN          NaN
# 2020-10-23  49.617932  3.193143  2.758083     NaN          NaN          NaN
# 2020-10-26  51.658768  3.159857  2.746508     NaN          NaN          NaN
#
#             Num_STD_from_SMA_20  Close_Chg_Amt  Prev_Pos_Neg_Vol     Prev_OBV  \
# 2020-10-19                  NaN         -2.960       -92366893.0 -154516677.0
# 2020-10-20                  NaN          1.500      -100858537.0 -255375214.0
# 2020-10-21                  NaN         -0.640       103813586.0 -151561628.0
# 2020-10-22                  NaN         -1.086       -73640108.0 -225201736.0
# 2020-10-23                  NaN         -0.724       -86318174.0 -311519910.0
# 2020-10-26                  NaN          0.010       -68258650.0 -379778560.0
#
#             Sto_Osc_K_RT  Sto_Osc_D_RT
# 2020-10-19           NaN           NaN
# 2020-10-20     30.523918           NaN
# 2020-10-21     34.396355           NaN
# 2020-10-22     39.573820     38.298841
# 2020-10-23     31.050228     31.033563
# 2020-10-26      5.711921     17.946591
# (2648050, 61)

# %% [markdown]
# There are certain metrics that I won't implement into the model yet; notably, I'll leave out MACD (because it indicates entry and exit signals, and my outcome variables don't care about intraday trading) and VWAP (because it uses 1-minute data that I haven't integrated yet).

# %% [markdown]
# ## Downloading the featured engineered day data for use in LSTM models
# Now that we've performed and thoroughly checked our feature engineering process, we can save this data for use in our modeling steps next.

# %%
# Saving my data_df into a file on my SSD
output_folder_path = "/Volumes/T7/Data_For_ML_Modeling"
file_path = os.path.join(output_folder_path, "Filtered_Cleaned_FE_Day_Data_2025_04_27.parquet")
data_df.to_parquet(file_path)

# %%
# Checking to make sure the file save worked
pd.read_parquet(file_path)
# Out:
#              Datetime    Open     High       Low    Close       Volume  \
# 2020-10-01 2020-10-01  117.70  117.720  115.8300  116.800   92076075.0
# 2020-10-02 2020-10-02  112.84  115.370  112.2200  113.020  116084401.0
# 2020-10-05 2020-10-05  113.92  116.650  113.5500  116.540   84421170.0
# 2020-10-06 2020-10-06  115.68  116.120  112.2500  113.160  132805466.0
# 2020-10-07 2020-10-07  114.64  115.550  114.1300  115.050   78303638.0
# ...               ...     ...      ...       ...      ...          ...
# 2024-12-04 2024-12-04    1.30    1.300    1.1800    1.180    3412081.0
# 2024-12-05 2024-12-05    1.21    1.210    1.0850    1.159    4859358.0
# 2024-12-06 2024-12-06    1.15    1.370    1.1450    1.365    4244740.0
# 2024-12-09 2024-12-09    1.37    1.550    1.3591    1.430    6100859.0
# 2024-12-10 2024-12-10    1.50    1.715    1.3800    1.650   12382855.0
#
#              PM_High    PM_Low  PM_Volume Ticker  PM_High_0927  PM_Low_0927  \
# 2020-10-01  118.1000  116.5100  1755406.0   AAPL      118.1000     116.5100
# 2020-10-02  117.0800  112.5600  4460967.0   AAPL      117.0800     112.7000
# 2020-10-05  114.7100  113.3000  1690948.0   AAPL      114.7100     113.3000
# 2020-10-06  116.7900  115.2300  1358666.0   AAPL      116.7900     115.2300
# 2020-10-07  114.7500  113.1340  2071097.0   AAPL      114.7500     113.1340
# ...              ...       ...        ...    ...           ...          ...
# 2024-12-04    1.3000    1.2800    18315.0     WW        1.3000       1.2800
# 2024-12-05    1.2300    1.1700    82055.0     WW        1.2300       1.1700
# 2024-12-06    1.1799    1.1118    27760.0     WW        1.1799       1.1118
# 2024-12-09    1.3900    1.3500    17138.0     WW        1.3900       1.3500
# 2024-12-10    1.5500    1.3900   155524.0     WW        1.5500       1.3900
#
#             PM_Close_0927  PM_Volume_0927  PM_High_0928  PM_Low_0928  \
# 2020-10-01       117.4500       1690772.0      118.1000     116.5100
# 2020-10-02       113.0000       4319384.0      117.0800     112.5600
# 2020-10-05       113.9700       1671728.0      114.7100     113.3000
# 2020-10-06       116.0100       1303941.0      116.7900     115.2300
# 2020-10-07       114.7000       2032261.0      114.7500     113.1340
# ...                   ...             ...           ...          ...
# 2024-12-04         1.3000         18315.0        1.3000       1.2800
# 2024-12-05         1.2100         82055.0        1.2300       1.1700
# 2024-12-06         1.1799         27760.0        1.1799       1.1118
# 2024-12-09         1.3800         17138.0        1.3900       1.3500
# 2024-12-10         1.4902        155524.0        1.5500       1.3900
#
#             PM_Close_0928  PM_Volume_0928  Rank                    Name  \
# 2020-10-01       117.6800       1726947.0     1              Apple Inc.
# 2020-10-02       112.7500       4389769.0     2              Apple Inc.
# 2020-10-05       113.9200       1685852.0     3              Apple Inc.
# 2020-10-06       115.8500       1331333.0     4              Apple Inc.
# 2020-10-07       114.6000       2042679.0     5              Apple Inc.
# ...                   ...             ...   ...                     ...
# 2024-12-04         1.3000         18315.0  1051  WW International, Inc.
# 2024-12-05         1.2100         82055.0  1052  WW International, Inc.
# 2024-12-06         1.1799         27760.0  1053  WW International, Inc.
# 2024-12-09         1.3800         17138.0  1054  WW International, Inc.
# 2024-12-10         1.4902        155524.0  1055  WW International, Inc.
#
#                Sub_Industry_Orig                   Sub_Industry  \
# 2020-10-01  Consumer Electronics           Consumer Electronics
# 2020-10-02  Consumer Electronics           Consumer Electronics
# 2020-10-05  Consumer Electronics           Consumer Electronics
# 2020-10-06  Consumer Electronics           Consumer Electronics
# 2020-10-07  Consumer Electronics           Consumer Electronics
# ...                          ...                            ...
# 2024-12-04     Personal Services  Specialized Consumer Services
# 2024-12-05     Personal Services  Specialized Consumer Services
# 2024-12-06     Personal Services  Specialized Consumer Services
# 2024-12-09     Personal Services  Specialized Consumer Services
# 2024-12-10     Personal Services  Specialized Consumer Services
#
#                                  Industry               Industry_Group  \
# 2020-10-01             Household Durables  Consumer Durables & Apparel
# 2020-10-02             Household Durables  Consumer Durables & Apparel
# 2020-10-05             Household Durables  Consumer Durables & Apparel
# 2020-10-06             Household Durables  Consumer Durables & Apparel
# 2020-10-07             Household Durables  Consumer Durables & Apparel
# ...                                   ...                          ...
# 2024-12-04  Diversified Consumer Services            Consumer Services
# 2024-12-05  Diversified Consumer Services            Consumer Services
# 2024-12-06  Diversified Consumer Services            Consumer Services
# 2024-12-09  Diversified Consumer Services            Consumer Services
# 2024-12-10  Diversified Consumer Services            Consumer Services
#
#                             Sector    Market_Cap  Close_Open_Diff  \
# 2020-10-01  Consumer Discretionary  2.918340e+12           -0.900
# 2020-10-02  Consumer Discretionary  2.918340e+12            0.180
# 2020-10-05  Consumer Discretionary  2.918340e+12            2.620
# 2020-10-06  Consumer Discretionary  2.918340e+12           -2.520
# 2020-10-07  Consumer Discretionary  2.918340e+12            0.410
# ...                            ...           ...              ...
# 2024-12-04  Consumer Discretionary  1.242000e+07           -0.120
# 2024-12-05  Consumer Discretionary  1.242000e+07           -0.051
# 2024-12-06  Consumer Discretionary  1.242000e+07            0.215
# 2024-12-09  Consumer Discretionary  1.242000e+07            0.060
# 2024-12-10  Consumer Discretionary  1.242000e+07            0.150
#
#             Close_Open_Diff_Perc  Close_Open_Diff_Binary  \
# 2020-10-01             -0.764656                   False
# 2020-10-02              0.159518                    True
# 2020-10-05              2.299860                    True
# 2020-10-06             -2.178423                   False
# 2020-10-07              0.357641                    True
# ...                          ...                     ...
# 2024-12-04             -9.230769                   False
# 2024-12-05             -4.214876                   False
# 2024-12-06             18.695652                    True
# 2024-12-09              4.379562                    True
# 2024-12-10             10.000000                    True
#
#             Close_Open_Diff_Ternary     PDO      PDH       PDL      PDC  \
# 2020-10-01                        0     NaN      NaN       NaN      NaN
# 2020-10-02                        1  117.70  117.720  115.8300  116.800
# 2020-10-05                        2  112.84  115.370  112.2200  113.020
# 2020-10-06                        0  113.92  116.650  113.5500  116.540
# 2020-10-07                        1  115.68  116.120  112.2500  113.160
# ...                             ...     ...      ...       ...      ...
# 2024-12-04                        0    1.29    1.315    1.2550    1.290
# 2024-12-05                        0    1.30    1.300    1.1800    1.180
# 2024-12-06                        2    1.21    1.210    1.0850    1.159
# 2024-12-09                        2    1.15    1.370    1.1450    1.365
# 2024-12-10                        2    1.37    1.550    1.3591    1.430
#
#                     PDV  PD_PM_V_0927  PD_PM_V_0928  Gap_from_PDC  \
# 2020-10-01          NaN           NaN           NaN           NaN
# 2020-10-02   92076075.0     1690772.0     1726947.0     -0.034675
# 2020-10-05  116084401.0     4319384.0     4389769.0      0.007963
# 2020-10-06   84421170.0     1671728.0     1685852.0     -0.005921
# 2020-10-07  132805466.0     1303941.0     1331333.0      0.012725
# ...                 ...           ...           ...           ...
# 2024-12-04    1407225.0       20409.0       20409.0      0.007752
# 2024-12-05    3412081.0       18315.0       18315.0      0.025424
# 2024-12-06    4859358.0       82055.0       82055.0      0.018033
# 2024-12-09    4244740.0       27760.0       27760.0      0.010989
# 2024-12-10    6100859.0       17138.0       17138.0      0.042098
#
#             Gap_Binary_Threshold  Daily_Range_Gap_Up  DR_Gap_Up_Binary  \
# 2020-10-01                 False                 NaN             False
# 2020-10-02                  True            0.000000             False
# 2020-10-05                 False            0.000000             False
# 2020-10-06                 False            0.000000             False
# 2020-10-07                 False            0.000000             False
# ...                          ...                 ...               ...
# 2024-12-04                 False            0.000000             False
# 2024-12-05                  True            0.000000             False
# 2024-12-06                 False            0.000000             False
# 2024-12-09                 False            0.007299              True
# 2024-12-10                  True            0.000000             False
#
#             Daily_Range_Gap_Down  DR_Gap_Down_Binary  Avg_PM_Vol_Prev_14D  \
# 2020-10-01                   NaN               False                  NaN
# 2020-10-02             -0.026591                True                  NaN
# 2020-10-05              0.000000               False                  NaN
# 2020-10-06              0.000000               False                  NaN
# 2020-10-07              0.000000               False                  NaN
# ...                          ...                 ...                  ...
# 2024-12-04              0.000000               False         32507.071429
# 2024-12-05              0.000000               False         30553.500000
# 2024-12-06              0.000000               False         34167.214286
# 2024-12-09              0.000000               False         35340.857143
# 2024-12-10              0.000000               False         34212.000000
#
#             PM_Vol_Change  SMA_Prev_14  SMA_Prev_50  EMA_Prev_9  EMA_Prev_20  \
# 2020-10-01            NaN          NaN          NaN         NaN          NaN
# 2020-10-02            NaN          NaN          NaN         NaN          NaN
# 2020-10-05            NaN          NaN          NaN         NaN          NaN
# 2020-10-06            NaN          NaN          NaN         NaN          NaN
# 2020-10-07            NaN          NaN          NaN         NaN          NaN
# ...                   ...          ...          ...         ...          ...
# 2024-12-04      -0.436584     1.078021     1.099576    1.196333     1.124568
# 2024-12-05       1.685617     1.096964     1.106504    1.193067     1.129847
# 2024-12-06      -0.187525     1.112279     1.113304    1.186253     1.132624
# 2024-12-09      -0.515066     1.146350     1.123736    1.222003     1.154755
# 2024-12-10       3.545890     1.186607     1.135718    1.263602     1.180969
#
#                RSI_14    ATR_14   NATR_14    SMA_20  Upper_BBand  Lower_BBand  \
# 2020-10-01        NaN       NaN       NaN       NaN          NaN          NaN
# 2020-10-02        NaN       NaN       NaN       NaN          NaN          NaN
# 2020-10-05        NaN       NaN       NaN       NaN          NaN          NaN
# 2020-10-06        NaN       NaN       NaN       NaN          NaN          NaN
# 2020-10-07        NaN       NaN       NaN       NaN          NaN          NaN
# ...               ...       ...       ...       ...          ...          ...
# 2024-12-04  76.318666  0.100429  7.785161  1.062825     1.401996     0.723654
# 2024-12-05  65.949519  0.106143  8.995157  1.065370     1.397785     0.732955
# 2024-12-06  68.538041  0.109950  9.486626  1.069815     1.402207     0.737423
# 2024-12-09  76.589356  0.115464  8.458922  1.105585     1.467448     0.743722
# 2024-12-10  78.685897  0.133571  9.340659  1.136825     1.532637     0.741013
#
#             Num_STD_from_SMA_20  Close_Chg_Amt  Prev_Pos_Neg_Vol     Prev_OBV  \
# 2020-10-01                  NaN            NaN               0.0          0.0
# 2020-10-02                  NaN         -3.780               0.0          0.0
# 2020-10-05                  NaN          3.520      -116084401.0 -116084401.0
# 2020-10-06                  NaN         -3.380        84421170.0  -31663231.0
# 2020-10-07                  NaN          1.890      -132805466.0 -164468697.0
# ...                         ...            ...               ...          ...
# 2024-12-04             1.398556         -0.110         1407225.0  164361463.0
# 2024-12-05             0.870178         -0.021        -3412081.0  160949382.0
# 2024-12-06             0.662382          0.206        -4859358.0  156090024.0
# 2024-12-09             1.516677          0.065         4244740.0  160334764.0
# 2024-12-10             1.785568          0.220         6100859.0  166435623.0
#
#             Sto_Osc_K_RT  Sto_Osc_D_RT
# 2020-10-01           NaN           NaN
# 2020-10-02           NaN           NaN
# 2020-10-05           NaN           NaN
# 2020-10-06           NaN           NaN
# 2020-10-07           NaN           NaN
# ...                  ...           ...
# 2024-12-04     85.446607     83.930629
# 2024-12-05     69.074040     72.105997
# 2024-12-06     63.598326     62.337032
# 2024-12-09     98.208848     85.092113
# 2024-12-10     91.205882     90.590337
#
# [2648050 rows x 61 columns]
